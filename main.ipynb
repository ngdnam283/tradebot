# %%
import threading
import time
from execution import strategy_execute # Import the execution logic from your execution.py
from data_request import run_websocket_for_pairs  # Import data fetching from your data_request.py
from performance import performance_table_create

# %%
def main(pair):
    # Create threads for data fetching and trading execution
    data_thread = threading.Thread(target=run_websocket_for_pairs, args=(pair,))
    trade_thread = threading.Thread(target=strategy_execute, args=(pair,))

    # Start the threads
    data_thread.start()
    trade_thread.start()

    # Join the threads (wait for them to finish, but they will run indefinitely)
    data_thread.join()
    trade_thread.join()

# %%
if __name__ == "__main__":
    trading_pair = "BTCUSDT"  # Replace with the desired pair
    performance_table_create()
    main(trading_pair)
# Out:
# Performance table is ready.
# Table for BTCUSDT with 200 slots is ready.
# New data detected at 2024-12-09 21:28:00, executing strategy...
# WebSocket connected successfully!
# Inserted into slot 46: close=99029.52, timestamp=2024-12-09 21:29:00
# New data detected at 2024-12-09 21:29:00, executing strategy...
# Inserted into slot 47: close=98964.0, timestamp=2024-12-09 21:30:00
# New data detected at 2024-12-09 21:30:00, executing strategy...
# Inserted into slot 48: close=99195.11, timestamp=2024-12-09 21:31:00
# New data detected at 2024-12-09 21:31:00, executing strategy...
# Inserted into slot 49: close=99298.76, timestamp=2024-12-09 21:32:00
# New data detected at 2024-12-09 21:32:00, executing strategy...
# Inserted into slot 50: close=99075.99, timestamp=2024-12-09 21:33:00
# New data detected at 2024-12-09 21:33:00, executing strategy...
# Inserted into slot 51: close=98900.01, timestamp=2024-12-09 21:34:00
# New data detected at 2024-12-09 21:34:00, executing strategy...
# Inserted into slot 52: close=99157.11, timestamp=2024-12-09 21:35:00
# New data detected at 2024-12-09 21:35:00, executing strategy...
# Inserted into slot 53: close=99264.0, timestamp=2024-12-09 21:36:00
# New data detected at 2024-12-09 21:36:00, executing strategy...
# Buy signal detected! Placing order...
# Order placed successfully: {'symbol': 'BTCUSDT', 'orderId': 11711284, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJa17d0f105a7b9255507227', 'transactTime': 1733755029488, 'price': '0.00000000', 'origQty': '0.00020000', 'executedQty': '0.00020000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '19.84337200', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1733755029488, 'fills': [{'price': '99216.86000000', 'qty': '0.00020000', 'commission': '0.00000000', 'commissionAsset': 'BTC', 'tradeId': 3953727}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
# Inserted into slot 54: close=99266.97, timestamp=2024-12-09 21:37:00
# New data detected at 2024-12-09 21:37:00, executing strategy...
# MA9 value: 99127.94111111111
# Inserted into slot 55: close=99264.13, timestamp=2024-12-09 21:38:00
# New data detected at 2024-12-09 21:38:00, executing strategy...
# MA9 value: 99154.0088888889
# Inserted into slot 56: close=99364.0, timestamp=2024-12-09 21:39:00
# New data detected at 2024-12-09 21:39:00, executing strategy...
# MA9 value: 99198.45333333334
# Inserted into slot 57: close=99463.08, timestamp=2024-12-09 21:40:00
# New data detected at 2024-12-09 21:40:00, executing strategy...
# MA9 value: 99228.22777777778
# Inserted into slot 58: close=99532.46, timestamp=2024-12-09 21:41:00
# New data detected at 2024-12-09 21:41:00, executing strategy...
# MA9 value: 99254.19444444444
# Inserted into slot 59: close=99593.97, timestamp=2024-12-09 21:42:00
# New data detected at 2024-12-09 21:42:00, executing strategy...
# MA9 value: 99311.74777777778
# Inserted into slot 60: close=99559.93, timestamp=2024-12-09 21:43:00
# New data detected at 2024-12-09 21:43:00, executing strategy...
# MA9 value: 99385.07222222221
# Inserted into slot 61: close=99598.4, timestamp=2024-12-09 21:44:00
# New data detected at 2024-12-09 21:44:00, executing strategy...
# MA9 value: 99434.10444444446
# Inserted into slot 62: close=99791.99, timestamp=2024-12-09 21:45:00
# New data detected at 2024-12-09 21:45:00, executing strategy...
# MA9 value: 99492.77
# Inserted into slot 63: close=99838.93, timestamp=2024-12-09 21:46:00
# New data detected at 2024-12-09 21:46:00, executing strategy...
# MA9 value: 99556.32111111112
# Inserted into slot 64: close=99943.99, timestamp=2024-12-09 21:47:00
# New data detected at 2024-12-09 21:47:00, executing strategy...
# MA9 value: 99631.86111111111
# Inserted into slot 65: close=99992.02, timestamp=2024-12-09 21:48:00
# New data detected at 2024-12-09 21:48:00, executing strategy...
# MA9 value: 99701.64111111111
# Inserted into slot 66: close=100099.99, timestamp=2024-12-09 21:49:00
# New data detected at 2024-12-09 21:49:00, executing strategy...
# MA9 value: 99772.4088888889
# Inserted into slot 67: close=100084.82, timestamp=2024-12-09 21:50:00
# New data detected at 2024-12-09 21:50:00, executing strategy...
# MA9 value: 99833.78222222222
# Inserted into slot 68: close=100220.0, timestamp=2024-12-09 21:51:00
# New data detected at 2024-12-09 21:51:00, executing strategy...
# MA9 value: 99903.3411111111
# Inserted into slot 69: close=100183.34, timestamp=2024-12-09 21:52:00
# New data detected at 2024-12-09 21:52:00, executing strategy...
# MA9 value: 99972.6088888889
# Inserted into slot 70: close=100199.99, timestamp=2024-12-09 21:53:00
# New data detected at 2024-12-09 21:53:00, executing strategy...
# MA9 value: 100039.45222222223
# Inserted into slot 71: close=100165.32, timestamp=2024-12-09 21:54:00
# New data detected at 2024-12-09 21:54:00, executing strategy...
# MA9 value: 100080.93333333333
# Inserted into slot 72: close=100281.29, timestamp=2024-12-09 21:55:00
# New data detected at 2024-12-09 21:55:00, executing strategy...
# MA9 value: 100130.08444444445
# Inserted into slot 73: close=100356.0, timestamp=2024-12-09 21:56:00
# New data detected at 2024-12-09 21:56:00, executing strategy...
# MA9 value: 100175.86333333334
# Inserted into slot 74: close=100302.99, timestamp=2024-12-09 21:57:00
# New data detected at 2024-12-09 21:57:00, executing strategy...
# MA9 value: 100210.41555555555
# Inserted into slot 75: close=100306.34, timestamp=2024-12-09 21:58:00
# New data detected at 2024-12-09 21:58:00, executing strategy...
# MA9 value: 100233.34333333334
# Inserted into slot 76: close=100156.26, timestamp=2024-12-09 21:59:00
# New data detected at 2024-12-09 21:59:00, executing strategy...
# MA9 value: 100241.28111111111
# Inserted into slot 77: close=100350.0, timestamp=2024-12-09 22:00:00
# New data detected at 2024-12-09 22:00:00, executing strategy...
# MA9 value: 100255.72555555556
# Inserted into slot 78: close=100408.0, timestamp=2024-12-09 22:01:00
# New data detected at 2024-12-09 22:01:00, executing strategy...
# MA9 value: 100280.68777777778
# Inserted into slot 79: close=100289.26, timestamp=2024-12-09 22:02:00
# New data detected at 2024-12-09 22:02:00, executing strategy...
# MA9 value: 100290.60666666666
# Inserted into slot 80: close=100268.03, timestamp=2024-12-09 22:03:00
# New data detected at 2024-12-09 22:03:00, executing strategy...
# MA9 value: 100302.01888888888
# Inserted into slot 81: close=100136.38, timestamp=2024-12-09 22:04:00
# New data detected at 2024-12-09 22:04:00, executing strategy...
# MA9 value: 100285.91777777778
# Inserted into slot 82: close=99884.0, timestamp=2024-12-09 22:05:00
# New data detected at 2024-12-09 22:05:00, executing strategy...
# MA9 value: 100233.47333333333
# Inserted into slot 83: close=99827.99, timestamp=2024-12-09 22:06:00
# New data detected at 2024-12-09 22:06:00, executing strategy...
# MA9 value: 100180.69555555556
# Inserted into slot 84: close=99747.86, timestamp=2024-12-09 22:07:00
# New data detected at 2024-12-09 22:07:00, executing strategy...
# MA9 value: 100118.64222222223
# Inserted into slot 85: close=99690.83, timestamp=2024-12-09 22:08:00
# New data detected at 2024-12-09 22:08:00, executing strategy...
# MA9 value: 100066.92777777778
# Inserted into slot 86: close=99554.67, timestamp=2024-12-09 22:09:00
# New data detected at 2024-12-09 22:09:00, executing strategy...
# MA9 value: 99978.55777777778
# Inserted into slot 87: close=99725.01, timestamp=2024-12-09 22:10:00
# New data detected at 2024-12-09 22:10:00, executing strategy...
# MA9 value: 99902.67
# Inserted into slot 88: close=99495.98, timestamp=2024-12-09 22:11:00
# New data detected at 2024-12-09 22:11:00, executing strategy...
# MA9 value: 99814.52777777778
# Inserted into slot 89: close=99560.01, timestamp=2024-12-09 22:12:00
# New data detected at 2024-12-09 22:12:00, executing strategy...
# MA9 value: 99735.85888888889
# Inserted into slot 90: close=99435.99, timestamp=2024-12-09 22:13:00
# New data detected at 2024-12-09 22:13:00, executing strategy...
# MA9 value: 99658.03777777779
# Sell signal due to MA crossover: MA9 crossed below MA50 or MA100
# Sell signal triggered based on crossover, profit/loss conditions. Placing sell order...
# Sell order placed successfully: {'symbol': 'BTCUSDT', 'orderId': 11727000, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ81f5cf61cafdf3814b7777', 'transactTime': 1733757250560, 'price': '0.00000000', 'origQty': '0.00020000', 'executedQty': '0.00020000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '19.97174000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'workingTime': 1733757250560, 'fills': [{'price': '99858.70000000', 'qty': '0.00020000', 'commission': '0.00000000', 'commissionAsset': 'USDT', 'tradeId': 3958747}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
# Performance data for BTCUSDT inserted successfully.
# Inserted into slot 91: close=99420.01, timestamp=2024-12-09 22:14:00
# New data detected at 2024-12-09 22:14:00, executing strategy...
# Inserted into slot 92: close=99248.01, timestamp=2024-12-09 22:15:00
# New data detected at 2024-12-09 22:15:00, executing strategy...
# Inserted into slot 93: close=98980.0, timestamp=2024-12-09 22:16:00
# New data detected at 2024-12-09 22:16:00, executing strategy...
# Inserted into slot 101: close=99031.64, timestamp=2024-12-09 22:17:00
# New data detected at 2024-12-09 22:17:00, executing strategy...
# Inserted into slot 102: close=98744.0, timestamp=2024-12-09 22:18:00
# New data detected at 2024-12-09 22:18:00, executing strategy...
# Inserted into slot 103: close=98608.79, timestamp=2024-12-09 22:19:00
# New data detected at 2024-12-09 22:19:00, executing strategy...
# Inserted into slot 104: close=98740.01, timestamp=2024-12-09 22:20:00
# New data detected at 2024-12-09 22:20:00, executing strategy...
# Inserted into slot 105: close=98684.15, timestamp=2024-12-09 22:21:00
# New data detected at 2024-12-09 22:21:00, executing strategy...
# Inserted into slot 106: close=98644.0, timestamp=2024-12-09 22:22:00
# New data detected at 2024-12-09 22:22:00, executing strategy...
# Inserted into slot 107: close=98512.67, timestamp=2024-12-09 22:23:00
# New data detected at 2024-12-09 22:23:00, executing strategy...
# Inserted into slot 108: close=98584.0, timestamp=2024-12-09 22:24:00
# New data detected at 2024-12-09 22:24:00, executing strategy...
# Inserted into slot 109: close=98522.12, timestamp=2024-12-09 22:25:00
# New data detected at 2024-12-09 22:25:00, executing strategy...
# Inserted into slot 110: close=98428.0, timestamp=2024-12-09 22:26:00
# New data detected at 2024-12-09 22:26:00, executing strategy...
# Inserted into slot 111: close=98345.14, timestamp=2024-12-09 22:27:00
# New data detected at 2024-12-09 22:27:00, executing strategy...
# Inserted into slot 112: close=98202.99, timestamp=2024-12-09 22:28:00
# New data detected at 2024-12-09 22:28:00, executing strategy...
# Inserted into slot 113: close=98279.99, timestamp=2024-12-09 22:29:00
# New data detected at 2024-12-09 22:29:00, executing strategy...
# Inserted into slot 114: close=98524.98, timestamp=2024-12-09 22:30:00
# New data detected at 2024-12-09 22:30:00, executing strategy...
# Inserted into slot 115: close=98280.01, timestamp=2024-12-09 22:31:00
# New data detected at 2024-12-09 22:31:00, executing strategy...
# Inserted into slot 116: close=98110.0, timestamp=2024-12-09 22:32:00
# New data detected at 2024-12-09 22:32:00, executing strategy...
# Inserted into slot 117: close=98027.0, timestamp=2024-12-09 22:33:00
# New data detected at 2024-12-09 22:33:00, executing strategy...
# Inserted into slot 118: close=98157.04, timestamp=2024-12-09 22:34:00
# New data detected at 2024-12-09 22:34:00, executing strategy...
# Inserted into slot 119: close=97829.59, timestamp=2024-12-09 22:35:00
# New data detected at 2024-12-09 22:35:00, executing strategy...
# Inserted into slot 120: close=97842.69, timestamp=2024-12-09 22:36:00
# New data detected at 2024-12-09 22:36:00, executing strategy...
# Inserted into slot 121: close=97799.43, timestamp=2024-12-09 22:37:00
# New data detected at 2024-12-09 22:37:00, executing strategy...
# Inserted into slot 122: close=97746.92, timestamp=2024-12-09 22:38:00
# New data detected at 2024-12-09 22:38:00, executing strategy...
# Inserted into slot 123: close=97952.23, timestamp=2024-12-09 22:39:00
# New data detected at 2024-12-09 22:39:00, executing strategy...
# Inserted into slot 124: close=97790.21, timestamp=2024-12-09 22:40:00
# New data detected at 2024-12-09 22:40:00, executing strategy...
# Inserted into slot 125: close=97812.0, timestamp=2024-12-09 22:41:00
# New data detected at 2024-12-09 22:41:00, executing strategy...
# Inserted into slot 126: close=97782.0, timestamp=2024-12-09 22:42:00
# New data detected at 2024-12-09 22:42:00, executing strategy...
# Inserted into slot 127: close=97746.2, timestamp=2024-12-09 22:43:00
# New data detected at 2024-12-09 22:43:00, executing strategy...
# Inserted into slot 128: close=97847.98, timestamp=2024-12-09 22:44:00
# New data detected at 2024-12-09 22:44:00, executing strategy...
# Inserted into slot 129: close=98060.01, timestamp=2024-12-09 22:45:00
# New data detected at 2024-12-09 22:45:00, executing strategy...
# Inserted into slot 130: close=97876.0, timestamp=2024-12-09 22:46:00
# New data detected at 2024-12-09 22:46:00, executing strategy...
